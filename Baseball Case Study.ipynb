# %% [markdown]
# Baseball Case Study
#
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)

# %%
# importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset
df=pd.read_csv('baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#checking shape of the data
df.shape
# Out:
# (30, 17)

# %%
#checking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#checking null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# as we can see no null values is perenent in the data set

# %%
# basisc info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Visualization

# %%
sns.scatterplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot(x='BB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.scatterplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.scatterplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
sns.pairplot(df)

# %%
sns.distplot(df["W"], kde=True)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df["R"], kde=True)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df["AB"], kde=True)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df["H"], kde=True)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df["2B"], kde=True)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df["3B"], kde=True)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df["HR"], kde=True)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df["BB"], kde=True)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df["SO"], kde=True)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df["SB"], kde=True)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df["RA"], kde=True)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df["RA"], kde=True)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df["ER"], kde=True)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df["ERA"], kde=True)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df["CG"], kde=True)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df["SHO"], kde=True)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df["SV"], kde=True)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df["E"], kde=True)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation of the columns with the target

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
df.corr()["W"].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.0%")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()["W"].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target name', fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
# checking skewness
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Keeping +/-0.5 as the range for skewness, here are the columns which does not lie within this range
#
# column R, column H, column CG, column SV, column E

# %% [markdown]
# ### Checking outliers

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
sns.boxplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W'>

# %%
sns.boxplot(df["R"])
# Out:
# <AxesSubplot:xlabel='R'>

# %%
sns.boxplot(df["AB"])
# Out:
# <AxesSubplot:xlabel='AB'>

# %%
sns.boxplot(df["H"])
# Out:
# <AxesSubplot:xlabel='H'>

# %%
sns.boxplot(df["2B"])
# Out:
# <AxesSubplot:xlabel='2B'>

# %%
sns.boxplot(df["3B"])
# Out:
# <AxesSubplot:xlabel='3B'>

# %%
sns.boxplot(df["HR"])
# Out:
# <AxesSubplot:xlabel='HR'>

# %%
sns.boxplot(df["BB"])
# Out:
# <AxesSubplot:xlabel='BB'>

# %%
sns.boxplot(df["SO"])
# Out:
# <AxesSubplot:xlabel='SO'>

# %%
sns.boxplot(df["SB"])
# Out:
# <AxesSubplot:xlabel='SB'>

# %%
sns.boxplot(df["SB"])
# Out:
# <AxesSubplot:xlabel='SB'>

# %%
sns.boxplot(df["RA"])
# Out:
# <AxesSubplot:xlabel='RA'>

# %%
sns.boxplot(df["ER"])
# Out:
# <AxesSubplot:xlabel='ER'>

# %%
sns.boxplot(df["ERA"])
# Out:
# <AxesSubplot:xlabel='ERA'>

# %%
sns.boxplot(df["CG"])
# Out:
# <AxesSubplot:xlabel='CG'>

# %%
sns.boxplot(df["SHO"])
# Out:
# <AxesSubplot:xlabel='SHO'>

# %%
sns.boxplot(df["SV"])
# Out:
# <AxesSubplot:xlabel='SV'>

# %%
sns.boxplot(df["E"])
# Out:
# <AxesSubplot:xlabel='E'>

# %% [markdown]
# ### Seprating the columns into features and target

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# we can see skewness in most of our dataset, we will remove the skewness using power_transform function

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,40):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i}, the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At random state {i}, the training accuracy is: {r2_score(y_test,pred_test)}")
    print('\n')
# Out:
# At random state 0, the training accuracy is: 0.9609590618835543
# At random state 0, the training accuracy is: 0.6629341689506705
#
#
# At random state 1, the training accuracy is: 0.9715846357165405
# At random state 1, the training accuracy is: 0.3841724690075786
#
#
# At random state 2, the training accuracy is: 0.9898192153844548
# At random state 2, the training accuracy is: -2.081998955010787
#
#
# At random state 3, the training accuracy is: 0.9722553885185528
# At random state 3, the training accuracy is: 0.4618378970602377
#
#
# At random state 4, the training accuracy is: 0.964746149799658
# At random state 4, the training accuracy is: 0.4660685292728437
#
#
# At random state 5, the training accuracy is: 0.9503092887369992
# At random state 5, the training accuracy is: 0.7517105066858546
#
#
# At random state 6, the training accuracy is: 0.948947004521447
# At random state 6, the training accuracy is: 0.8376419521868339
#
#
# At random state 7, the training accuracy is: 0.9631978535911326
# At random state 7, the training accuracy is: -0.25547694158915535
#
#
# At random state 8, the training accuracy is: 0.9623956064118225
# At random state 8, the training accuracy is: 0.5868676500008577
#
#
# At random state 9, the training accuracy is: 0.9558190206474735
# At random state 9, the training accuracy is: 0.7290448155515925
#
#
# At random state 10, the training accuracy is: 0.9658380488238816
# At random state 10, the training accuracy is: -0.2279712919950747
#
#
# At random state 11, the training accuracy is: 0.9794801537272682
# At random state 11, the training accuracy is: 0.2481759765614716
#
#
# At random state 12, the training accuracy is: 0.9737413001008608
# At random state 12, the training accuracy is: -1.1916550064202482
#
#
# At random state 13, the training accuracy is: 0.9750450815078384
# At random state 13, the training accuracy is: 0.676707984334459
#
#
# At random state 14, the training accuracy is: 0.9469984720280225
# At random state 14, the training accuracy is: 0.7947948235207332
#
#
# At random state 15, the training accuracy is: 0.9709420941407676
# At random state 15, the training accuracy is: 0.08782646885313528
#
#
# At random state 16, the training accuracy is: 0.9858809375178788
# At random state 16, the training accuracy is: 0.2156636142748778
#
#
# At random state 17, the training accuracy is: 0.9749884441968527
# At random state 17, the training accuracy is: 0.2429837566512275
#
#
# At random state 18, the training accuracy is: 0.9619051538791019
# At random state 18, the training accuracy is: 0.44692713019862174
#
#
# At random state 19, the training accuracy is: 0.9495167250254274
# At random state 19, the training accuracy is: 0.838113419335654
#
#
# At random state 20, the training accuracy is: 0.9648282100620996
# At random state 20, the training accuracy is: 0.30103553183443355
#
#
# At random state 21, the training accuracy is: 0.9632922835126104
# At random state 21, the training accuracy is: 0.43748497306629985
#
#
# At random state 22, the training accuracy is: 0.9538756336575558
# At random state 22, the training accuracy is: -0.022968263180221937
#
#
# At random state 23, the training accuracy is: 0.9614513761755267
# At random state 23, the training accuracy is: 0.5703263346963161
#
#
# At random state 24, the training accuracy is: 0.9930550857101428
# At random state 24, the training accuracy is: -3.9281386887175183
#
#
# At random state 25, the training accuracy is: 0.9579610563737945
# At random state 25, the training accuracy is: 0.4181713062412423
#
#
# At random state 26, the training accuracy is: 0.9658277445021987
# At random state 26, the training accuracy is: 0.324133608651172
#
#
# At random state 27, the training accuracy is: 0.9552740421332101
# At random state 27, the training accuracy is: 0.6767959850140982
#
#
# At random state 28, the training accuracy is: 0.9597644213445621
# At random state 28, the training accuracy is: 0.6699377101719095
#
#
# At random state 29, the training accuracy is: 0.9511213168423279
# At random state 29, the training accuracy is: 0.8790507229532956
#
#
# At random state 30, the training accuracy is: 0.9494811939208996
# At random state 30, the training accuracy is: 0.8365092739163154
#
#
# At random state 31, the training accuracy is: 0.9951572148896561
# At random state 31, the training accuracy is: 0.2592083827638959
#
#
# At random state 32, the training accuracy is: 0.9631618129568901
# At random state 32, the training accuracy is: 0.24486497945420882
#
#
# At random state 33, the training accuracy is: 0.9828979279570369
# At random state 33, the training accuracy is: 0.7251644237527008
#
#
# At random state 34, the training accuracy is: 0.9721607076503062
# At random state 34, the training accuracy is: 0.7974272428667585
#
#
# At random state 35, the training accuracy is: 0.980068511522487
# At random state 35, the training accuracy is: 0.18097976995379672
#
#
# At random state 36, the training accuracy is: 0.9577869158330774
# At random state 36, the training accuracy is: 0.7342034319837716
#
#
# At random state 37, the training accuracy is: 0.9564708376178136
# At random state 37, the training accuracy is: 0.5924138149123603
#
#
# At random state 38, the training accuracy is: 0.9684911861559723
# At random state 38, the training accuracy is: 0.23284767333799095
#
#
# At random state 39, the training accuracy is: 0.9531716157253376
# At random state 39, the training accuracy is: 0.8073613092401453

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=29)

# %%
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.8790507229532956

# %% [markdown]
# ## Corss_validiation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}, and the accuracy for testing is {Test_accuracy}")
    print('\n')
# Out:
# At cross fold2 the cv score is -1.057932205834568 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold3 the cv score is 0.2258846016774 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold4 the cv score is 0.24952166654368527 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold5 the cv score is 0.04075540667465847 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold6 the cv score is 0.2515353093720216 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold7 the cv score is 0.3890804644289939 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold8 the cv score is 0.31937022109669355 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956
#
#
# At cross fold9 the cv score is -4.8090841203953385 and accuracy score for training is -0.13805227229725348, and the accuracy for testing is 0.8790507229532956

# %% [markdown]
# Since the number of folds don't have such impact on the accuracy and cv_score. So cv=5 is selected
#
# Here we have handled the problem of the overfitting and the underfitting by checking the training and testing score

# %%
plt.figure(figsize=(6,8))
plt.scatter(x=y_test,y=pred_test, color='r')
plt.plot(y_test, y_test, color='b')
plt.xlabel("Actual", fontsize=14)
plt.ylabel("Predicted", fontsize=14)
plt.title("Linear Regression", fontsize=18)
plt.show()

# %% [markdown]
# ### Regularization

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.linear_model import Lasso

parameters = {'alpha':[0.0001, 0.001, 0.01, 0.1, 1, 10],'random_state': list(range(0,10))}
ls = Lasso()
Clf=GridSearchCV(ls,parameters)
Clf.fit(x_train,y_train)

print(Clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
# final model training 
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train, y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 87.39265429517438

# %% [markdown]
# ### Ensemble techniques

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters= {'criterion':['mse','mae'], 'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mse", max_features="log2")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision = rf.predict(x_test)

rfs=r2_score(y_test, pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score: ',rfc*100)
# Out:
# R2 score: 78.5351460176991
# Cross Val Score:  -36.63942301305356

# %%
import pickle 
filename = 'baseball.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 78.5351460176991

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:], pred_decision[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#                0      1      2      3      4      5
# Predicted  88.95  88.98  74.84  72.54  79.83  76.77
# Orginal    88.95  88.98  74.84  72.54  79.83  76.77
